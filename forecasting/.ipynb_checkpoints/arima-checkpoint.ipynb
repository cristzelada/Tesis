# %%
import re
import os
import sys
import datetime
import itertools
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import statsmodels.tsa.api as smt

from matplotlib.pylab import rcParams
plt.rcParams['savefig.dpi'] = 250
plt.rcParams['figure.figsize'] = (18, 5)
plt.rcParams['text.latex.preamble'] = b"\usepackage{subdepth}, \usepackage{type1cm}"

pd.options.display.max_columns = 16
pd.options.display.max_rows = 16
pd.set_option('display.float_format', lambda x: '%.5f' % x)
np.set_printoptions(precision=5, suppress=True)

import warnings
warnings.filterwarnings('ignore')

from pandas.plotting import autocorrelation_plot

from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller, kpss

from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA

import statsmodels.formula.api as smf
import statsmodels.api as sm

import scipy.stats as scs
from ipywidgets import interactive, widgets, RadioButtons, ToggleButtons, Select, FloatSlider, FloatProgress
from IPython.display import set_matplotlib_formats, Image
from datetime import datetime

from math import sqrt
from sklearn.metrics import mean_squared_error

# %% [markdown]
# #### Visualizar la demanda como serie de tiempo

# %%
#serie de tiempo en grafico
dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m-%d')

#leer la data del excel de los huespedes.csv
demand_data = pd.read_csv('./data/DemandaInfo.csv', parse_dates=['time'], index_col='time',date_parser=dateparse)

#guardar en otra variable
demand_ts = demand_data['demand']

# %%
#Plot
plt.plot(demand_ts, linewidth=1)
plt.title(u'Reserva de habitaciones Hotel los Cocos', fontsize=16)
plt.ylabel(u'# Reservas')
plt.xlabel(u'Año')
plt.show()

# %%
#agrupamos los dias por semanas
demand_ts  = demand_data['demand'].resample('W').sum()

# %%
#Plot
plt.plot(demand_ts, linewidth=1)
plt.title(u'Reserva de habitaciones Hotel los Cocos', fontsize=16)
plt.ylabel(u'# Reservas')
plt.xlabel(u'Año')
plt.show()

# %%
demand_ts
# Out:
# time
# 2012-01-01     7
# 2012-01-08    26
# 2012-01-15    28
# 2012-01-22    35
# 2012-01-29    38
# 2012-02-05    26
# 2012-02-12    32
# 2012-02-19    28
#               ..
# 2019-04-14    34
# 2019-04-21    32
# 2019-04-28    24
# 2019-05-05    41
# 2019-05-12    28
# 2019-05-19    41
# 2019-05-26    27
# 2019-06-02    23
# Freq: W-SUN, Name: demand, Length: 388, dtype: int64

# %% [markdown]
# #### Analizis de la Serie

# %%
fig, axes = plt.subplots(2, 2, sharey=False, sharex=False)
fig.set_figwidth(14)
fig.set_figheight(8)
axes[0][0].plot(demand_ts.index, demand_ts, label='Original')
axes[0][0].plot(demand_ts.index, demand_ts.rolling(window=12).mean(), label='3-Months Rolling Mean')
axes[0][0].set_xlabel("Years")
axes[0][0].set_ylabel("Numero Reserva")
axes[0][0].set_title("3-Months Moving Average")
axes[0][0].legend(loc='best')
axes[0][1].plot(demand_ts.index, demand_ts, label='Original')
axes[0][1].plot(demand_ts.index, demand_ts.rolling(window=26).mean(), label='6-Months Rolling Mean')
axes[0][1].set_xlabel("Years")
axes[0][1].set_ylabel("Numero Reserva")
axes[0][1].set_title("6-Months Moving Average")
axes[0][1].legend(loc='best')
axes[1][0].plot(demand_ts.index, demand_ts, label='Original')
axes[1][0].plot(demand_ts.index, demand_ts.rolling(window=32).mean(), label='8-Months Rolling Mean')
axes[1][0].set_xlabel("Years")
axes[1][0].set_ylabel("Numero Reserva")
axes[1][0].set_title("8-Months Moving Average")
axes[1][0].legend(loc='best')
axes[1][1].plot(demand_ts.index, demand_ts, label='Original')
axes[1][1].plot(demand_ts.index, demand_ts.rolling(window=56).mean(), label='12-Months Rolling Mean')
axes[1][1].set_xlabel("Years")
axes[1][1].set_ylabel("Numero Reservas")
axes[1][1].set_title("12-Months Moving Average")
axes[1][1].legend(loc='best')
plt.tight_layout()
plt.show()

# %%
#Determing rolling statistics
rolmean = demand_ts.rolling(window=26).mean()
rolstd = demand_ts.rolling(window=26).std()

#Plot rolling statistics:
orig = plt.plot(demand_ts, label='Original')
mean = plt.plot(rolmean, label='Rolling Mean',color='red')
std = plt.plot(rolstd, label = 'Rolling Std',color='black')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)

# %%
# Perform Dickey-Fuller test:
from statsmodels.tsa.stattools import adfuller
print('Results of Dickey-Fuller Test:')
dftest = adfuller(demand_ts, autolag='AIC')
dfoutput = pd.Series(dftest[0:4], index=['Test Statistic', 'p-value', '#lags Used', 'Number of Observations Used'])
for key, value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -9.40508
# p-value                         0.00000
# #lags Used                      1.00000
# Number of Observations Used   386.00000
# Critical Value (1%)            -3.44741
# Critical Value (5%)            -2.86906
# Critical Value (10%)           -2.57077
# dtype: float64

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
from matplotlib import pyplot

pyplot.figure(figsize=(18, 6))
pyplot.subplot(211)
plot_acf(demand_ts, ax=pyplot.gca(), lags = 30)
pyplot.subplot(212)
plot_pacf(demand_ts, ax=pyplot.gca(), lags = 30)
pyplot.show()
plt.tight_layout()

# %% [markdown]
# #### Time Series Decomposition

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(demand_ts, freq=52)

plt.figure(figsize = (16,10))
trend = decomposition.trend
seasonal = decomposition.seasonal
residual = decomposition.resid

plt.subplot(411)
plt.title('Original')
plt.plot(demand_ts, label='Original')
plt.legend(loc='best')
plt.subplot(412)
plt.title('Trend')
plt.plot(trend, label='Trend')
plt.legend(loc='best')
plt.subplot(413)
plt.title('Seasonality')
plt.plot(seasonal,label='Seasonality')
plt.legend(loc='best')
plt.subplot(414)
plt.title('Residuals')
plt.plot(residual, label='Residuals')
plt.legend(loc='best')

plt.tight_layout()

# %% [markdown]
# #### Log transformation para hacer que los datos sean estacionarios en varianza

# %%
demand_ts_log = np.log10(demand_ts)
demand_ts_log.dropna(inplace=True)

plt.figure(figsize = (18,4))
plt.plot(demand_ts_log)
plt.xlabel('Years')
plt.ylabel('Demand')
# Out:
# Text(0, 0.5, 'Demand')

# %% [markdown]
# #### Difference log transform para hacer que los datos sean estacionarios tanto en la media como en varianza

# %%
demand_ts_log_diff = demand_ts_log.diff(periods=1) # same as ts_log_diff = ts_log - ts_log.shift(periods=1)
demand_ts_log_diff.dropna(inplace=True)

plt.figure(figsize = (18,4))
plt.plot(demand_ts_log_diff)
plt.xlabel('Years')
plt.ylabel('Demand')
# Out:
# Text(0, 0.5, 'Demand')

# %% [markdown]
# #### Plot ACF and PACF to identify potential AR and MA model

# %%
#ACF and PACF plots:
from statsmodels.tsa.stattools import acf, pacf

lag_acf = acf(demand_ts_log_diff, nlags=40)
lag_pacf = pacf(demand_ts_log_diff, nlags=40, method='ols')

# %%
#Plot ACF: 
plt.subplot(121) 
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(demand_ts_log_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(demand_ts_log_diff)),linestyle='--',color='gray')
plt.title('Autocorrelation Function')
# Out:
# Text(0.5, 1.0, 'Autocorrelation Function')

# %%
#Plot PACF:
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
plt.axhline(y=-1.96/np.sqrt(len(demand_ts_log_diff)),linestyle='--',color='gray')
plt.axhline(y=1.96/np.sqrt(len(demand_ts_log_diff)),linestyle='--',color='gray')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %% [markdown]
# #### Identificación del mejor modelo de ajuste ARIMA

# %%
from pyramid.arima import auto_arima
stepwise_model = auto_arima(demand_ts_log_diff, start_p=1, start_q=1,
                           max_p=3, max_q=3, m=48,
                           start_P=0, seasonal=True,
                           d=1, D=1, trace=True,
                           error_action='ignore',  
                           suppress_warnings=True, 
                           stepwise=True)
print(stepwise_model.aic())
# Out:
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 1, 48); AIC=-255.740, BIC=-236.625, Fit time=30.742 seconds
# Fit ARIMA: order=(0, 1, 0) seasonal_order=(0, 1, 0, 48); AIC=299.673, BIC=307.319, Fit time=0.972 seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(1, 1, 0, 48); AIC=11.919, BIC=27.211, Fit time=11.322 seconds
# Fit ARIMA: order=(0, 1, 1) seasonal_order=(0, 1, 1, 48); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 1, 48); AIC=-254.726, BIC=-231.788, Fit time=29.095 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 0, 48); AIC=-163.184, BIC=-147.892, Fit time=6.822 seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(0, 1, 2, 48); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 1) seasonal_order=(1, 1, 2, 48); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(2, 1, 1) seasonal_order=(0, 1, 1, 48); AIC=-272.903, BIC=-249.965, Fit time=40.794 seconds
# Fit ARIMA: order=(2, 1, 0) seasonal_order=(0, 1, 1, 48); AIC=-95.495, BIC=-76.380, Fit time=19.373 seconds
# Fit ARIMA: order=(2, 1, 2) seasonal_order=(0, 1, 1, 48); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(1, 1, 0) seasonal_order=(0, 1, 1, 48); AIC=-29.556, BIC=-14.263, Fit time=13.667 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(0, 1, 1, 48); AIC=-276.092, BIC=-245.508, Fit time=48.359 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(1, 1, 1, 48); AIC=-273.834, BIC=-239.427, Fit time=54.779 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(0, 1, 0, 48); AIC=-172.305, BIC=-145.544, Fit time=10.573 seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(0, 1, 2, 48); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(3, 1, 2) seasonal_order=(1, 1, 2, 48); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(0, 1, 1, 48); AIC=-291.539, BIC=-264.778, Fit time=44.771 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(1, 1, 1, 48); AIC=-285.889, BIC=-255.304, Fit time=46.047 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(0, 1, 0, 48); AIC=-186.086, BIC=-163.148, Fit time=11.235 seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(0, 1, 2, 48); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(3, 1, 1) seasonal_order=(1, 1, 2, 48); AIC=nan, BIC=nan, Fit time=nan seconds
# Fit ARIMA: order=(3, 1, 0) seasonal_order=(0, 1, 1, 48); AIC=-158.725, BIC=-135.786, Fit time=29.826 seconds
# Total fit time: 398.476 seconds
# -291.53887515470694

# %%
#Dividir datos de prueba y entrenamiento
train = demand_ts[:'2018']
test = demand_ts['2019':]

print(len(train))
print(len(test))
# Out:
# 366
# 22

# %%
best_model = sm.tsa.statespace.SARIMAX(demand_ts,
                                      order=(3, 1, 1),
                                      seasonal_order=(0, 1, 1, 52),
                                      enforce_stationarity=False,
                                      enforce_invertibility=False)
best_results = best_model.fit()

# %%
print(best_results.summary())
# Out:
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                             demand   No. Observations:                  388
# Model:             SARIMAX(3, 1, 1)x(0, 1, 1, 52)   Log Likelihood                -979.253
# Date:                            Fri, 05 Jul 2019   AIC                           1970.506
# Time:                                    20:04:21   BIC                           1992.337
# Sample:                                01-01-2012   HQIC                          1979.262
#                                      - 06-02-2019
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.0908      0.063      1.440      0.150      -0.033       0.214
# ar.L2          0.1096      0.067      1.629      0.103      -0.022       0.241
# ar.L3          0.0201      0.064      0.315      0.753      -0.105       0.145
# ma.L1         -0.9804      0.018    -53.976      0.000      -1.016      -0.945
# ma.S.L52      -0.6948      0.077     -8.969      0.000      -0.847      -0.543
# sigma2        59.1727      5.255     11.260      0.000      48.873      69.473
# ===================================================================================
# Ljung-Box (Q):                       16.08   Jarque-Bera (JB):                 1.30
# Prob(Q):                              1.00   Prob(JB):                         0.52
# Heteroskedasticity (H):               1.16   Skew:                             0.17
# Prob(H) (two-sided):                  0.48   Kurtosis:                         3.03
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
best_results.plot_diagnostics(figsize=(19, 13))
plt.show()

# %% [markdown]
# #### Predict demand on in-sample date using the best fit ARIMA model

# %%
pred = best_results.get_prediction(start=366, dynamic=False)
pred_ci = pred.conf_int()

# %%
pred.predicted_mean
# Out:
# time
# 2019-01-06   32.27035
# 2019-01-13   33.81413
# 2019-01-20   34.76178
# 2019-01-27   32.78542
# 2019-02-03   38.84701
# 2019-02-10   35.57084
# 2019-02-17   33.89281
# 2019-02-24   26.96408
# 2019-03-03   36.52207
# 2019-03-10   31.50395
# 2019-03-17   34.79921
# 2019-03-24   28.92120
# 2019-03-31   31.42906
# 2019-04-07   37.76297
# 2019-04-14   36.22596
# 2019-04-21   27.66476
# 2019-04-28   29.33671
# 2019-05-05   25.87757
# 2019-05-12   32.58245
# 2019-05-19   31.71567
# 2019-05-26   28.04309
# 2019-06-02   35.58499
# Freq: W-SUN, dtype: float64

# %%
ax = demand_ts['2017':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(20, 7))

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('Date')
ax.set_ylabel('Furniture Sales')
plt.legend()

plt.show()
plt.tight_layout()

# %% [markdown]
# #### Forecast sales using the best fit ARIMA model

# %%
FORECAST = 48
pred_uc = best_results.get_forecast(steps=FORECAST)
pred_ci = pred_uc.conf_int()

# %%
futureDates = pd.date_range(start = '2019-05-26', periods=FORECAST, freq='W')
pred_ci.index = futureDates
mean= pred_uc.predicted_mean

# %%
futureDF = pd.DataFrame(mean.values, index=futureDates)
futureDF
# Out:
#                   0
# 2019-05-26 28.75498
# 2019-06-02 25.29764
# 2019-06-09 29.34919
# 2019-06-16 32.90788
# 2019-06-23 27.21339
# 2019-06-30 28.85218
# 2019-07-07 26.38551
# 2019-07-14 26.20056
# ...             ...
# 2020-03-01 38.67947
# 2020-03-08 35.50505
# 2020-03-15 36.92484
# 2020-03-22 37.29515
# 2020-03-29 34.56752
# 2020-04-05 29.43745
# 2020-04-12 28.44859
# 2020-04-19 31.73280
#
# [48 rows x 1 columns]

# %%
fig,ax = plt.subplots()
ax.plot(demand_ts, label="Observed")
ax.plot(futureDF, label='Forecast', color='#ff0066');

  # draw confidence bound
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='#ff0066', alpha=.2);
 
ax.set_xlabel("Year")
ax.set_ylabel("Demand") 
ax.legend(loc='upper left')
fig.suptitle("Demand Forecast")
# Out:
# Text(0.5, 0.98, 'Demand Forecast')

# %%
from sklearn.metrics import r2_score, median_absolute_error, mean_absolute_error
from sklearn.metrics import median_absolute_error, mean_squared_error, mean_squared_log_error

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
mean_absolute_percentage_error(test, pred.predicted_mean)
# Out:
# 26.309893885248975

# %%
pd.set_option('display.max_columns', 3000)
pd.options.display.max_columns = 1600
pd.options.display.max_rows = 1600
# Out:
#                   0
# 2019-05-26 28.75498
# 2019-06-02 25.29764
# 2019-06-09 29.34919
# 2019-06-16 32.90788
# 2019-06-23 27.21339
# 2019-06-30 28.85218
# 2019-07-07 26.38551
# 2019-07-14 26.20056
# 2019-07-21 27.92645
# 2019-07-28 34.07613
# 2019-08-04 28.76646
# 2019-08-11 28.07020
# 2019-08-18 35.61715
# 2019-08-25 33.15432
# 2019-09-01 29.49220
# 2019-09-08 32.46766
# 2019-09-15 37.45303
# 2019-09-22 38.28270
# 2019-09-29 44.46745
# 2019-10-06 39.48825
# 2019-10-13 39.54432
# 2019-10-20 30.99053
# 2019-10-27 38.19723
# 2019-11-03 37.95951
# 2019-11-10 39.07743
# 2019-11-17 30.60176
# 2019-11-24 30.65348
# 2019-12-01 25.78899
# 2019-12-08 26.21282
# 2019-12-15 29.66021
# 2019-12-22 32.32806
# 2019-12-29 34.74869
# 2020-01-05 32.33882
# 2020-01-12 33.81837
# 2020-01-19 41.11716
# 2020-01-26 36.40488
# 2020-02-02 40.65598
# 2020-02-09 32.97904
# 2020-02-16 39.50707
# 2020-02-23 33.82358
# 2020-03-01 38.67947
# 2020-03-08 35.50505
# 2020-03-15 36.92484
# 2020-03-22 37.29515
# 2020-03-29 34.56752
# 2020-04-05 29.43745
# 2020-04-12 28.44859
# 2020-04-19 31.73280
