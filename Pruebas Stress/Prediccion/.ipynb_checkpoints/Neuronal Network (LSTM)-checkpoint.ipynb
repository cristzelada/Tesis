# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import os
import matplotlib
import matplotlib.pyplot as plt
import random
# %matplotlib inline
import shutil
import tensorflow.contrib.learn as tflearn
import tensorflow.contrib.layers as tflayers
from tensorflow.contrib.learn.python.learn import learn_runner
import tensorflow.contrib.metrics as metrics
import tensorflow.contrib.rnn as rnn
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20, 6

# %%
dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m-%d')
demand_data = pd.read_csv('DemandaInfo.csv', parse_dates=['time'], index_col='time',date_parser=dateparse)
demand_ts = demand_data['demand']

# %%
#Plot
plt.plot(demand_ts, linewidth=1)
plt.title(u'Reserva de habitaciones Hotel los Cocos', fontsize=16)
plt.ylabel(u'# Reservas')
plt.xlabel(u'Año')
plt.show()

# %%
#Dividir datos de prueba y entrenamiento
train = demand_ts[:'2018']
test = demand_ts['2019':]

print(len(train))
print(len(test))
# Out:
# 2555
# 151

# %%
#demand_ts['2012':'2018']

# %%
TS = np.array(demand_ts)
num_periods = 183
f_horizon = 1
x_data = TS[:(len(TS)-(len(TS)% num_periods))]
x_batches = x_data.reshape(-1, 1, 1)

y_data = TS[1:(len(TS)-(len(TS) % num_periods)) + f_horizon]
y_batches = y_data.reshape(-1, 1, 1)

# %%
#TS

# %%
print("x_data:")
print(x_data.shape)
#print("\n x_batches:")
#print(x_batches)
print("\n x_batches shape:")
print(x_batches.shape)

#print("\n y_data:")
#print(y_data)

print("\n y_data:")
print(y_data.shape)
#print("\n y_batches:")
#print(y_batches)
print("\n y_batches shape:")
print(y_batches.shape)
# Out:
# x_data:
# (2562,)
#
#  x_batches shape:
# (2562, 1, 1)
#
#  y_data:
# (2562,)
#
#  y_batches shape:
# (2562, 1, 1)

# %%
def test_data(series, forecast, num_periods):
    test_x_setup = TS[-(num_periods + forecast):]
    testX = test_x_setup[:num_periods].reshape(-1, 1, 1)
    testY = TS[-(num_periods):].reshape(-1, 1, 1)
    return testX,testY

X_test, Y_test = test_data(TS, f_horizon, num_periods)

# %%
print("\n X_test shape")
print(X_test.shape)

print("\n Y_test shape")
print(Y_test.shape)

print("\n X_test")
#print(X_test)
# Out:
#  X_test shape
# (183, 1, 1)
#
#  Y_test shape
# (183, 1, 1)
#
#  X_test

# %%
tf.reset_default_graph()

num_periods = 1
inputs = 1
hidden = 200
output = 1

X = tf.placeholder(tf.float32, [None, num_periods, inputs])
y = tf.placeholder(tf.float32, [None, num_periods, output])

basic_cell = tf.nn.rnn_cell.LSTMCell(num_units=hidden, activation=tf.nn.relu)
rnn_output, states = tf.nn.dynamic_rnn(basic_cell, X, dtype=tf.float32)

#BasicRNNCell
#BasicLSTMCell
learning_rate = 0.01

stacked_rnn_output = tf.reshape(rnn_output,[-1,hidden])
stacked_outputs = tf.layers.dense(stacked_rnn_output, output)
outputs = tf.reshape(stacked_outputs, [-1, num_periods, output])


loss = tf.reduce_sum(tf.square(outputs - y ))
optimizer = tf.train.AdamOptimizer(learning_rate=learning_rate)
training_op = optimizer.minimize(loss)

init = tf.global_variables_initializer()

# %%
epochs = 1000

with tf.Session() as sess:
    init.run()
    for ep in range(epochs):
        sess.run(training_op, feed_dict={X: x_batches, y: y_batches})
        if ep % 100 == 0:
            mse = loss.eval(feed_dict={X: x_batches, y: y_batches})
            print(ep, "\tMSE:", mse)
    y_pred = sess.run(outputs, feed_dict={X: X_test})
# Out:
# 0 	MSE: 526839.56
# 100 	MSE: 212746.08
# 200 	MSE: 209123.44
# 300 	MSE: 208907.77
# 400 	MSE: 208848.12
# 500 	MSE: 208799.84
# 600 	MSE: 208749.17
# 700 	MSE: 208685.89
# 800 	MSE: 208599.05
# 900 	MSE: 208509.86

# %%
y_pred.shape
# Out:
# (183, 1, 1)

# %%
indDates1 = pd.date_range(start = '2012-01-01', periods=len(X_test), freq='D')
indDates2 = pd.date_range(start = '2019-01-01', periods=len(Y_test), freq='D')

# %%
#Xtest = pd.DataFrame(X_test.ravel(), index=indDates1)
#Xtest

# %%
Ytest = pd.DataFrame(Y_test.ravel(), index=indDates2)
#Ytest

# %%
YPred = pd.DataFrame(y_pred.ravel(), index=indDates2)
#YPred

# %%
plt.title("Forecast vs Actual", fontsize=14)
#plt.plot( Xtest, 'blue', label="X Test", linewidth=0.7)
plt.plot( Ytest, 'black', label="Actual Test", linewidth=1)
plt.plot( YPred, 'orange', label="Forecast", linewidth=1.5)
plt.legend(loc="upper left")
plt.xlabel("Time Periods")

plt.show()

# %%
plt.title("Forecast vs Actual", fontsize=14)
plt.plot(pd.Series(np.ravel(Y_test)), 'b', label="Actual - Test")
plt.plot(pd.Series(np.ravel(y_pred)), 'r', label="Forecast")
plt.legend(loc="upper left")
plt.xlabel("Time Periods")

plt.show()

# %%
print("Y_test shape: ",Y_test.shape)
print("y_pred shape: ",y_pred.shape)
# Out:
# Y_test shape:  (183, 1, 1)
# y_pred shape:  (183, 1, 1)

# %%
from sklearn.metrics import r2_score, median_absolute_error, mean_absolute_error
from sklearn.metrics import median_absolute_error, mean_squared_error, mean_squared_log_error
from math import sqrt

# %% [markdown]
# #### MAPE (Mean Absolute Percentage Error)

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

mean_absolute_percentage_error(Y_test,y_pred )
# Out:
# 78.72202841189893

# %% [markdown]
# #### MAD (Median absolute deviation)

# %%
#median_absolute_error(Y_test,y_pred)

# %% [markdown]
# #### MAE (Mean Absolute Error)

# %%
#mean_absolute_error(Y_test,y_pred )

# %% [markdown]
# #### MSE (Mean Squared Error)

# %%
#mean_squared_error(Y_test,y_pred )

# %% [markdown]
# #### RMSE (Root Mean Square error)

# %%
#sqrt( mean_squared_error(Y_test,y_pred ) )

# %%
pd.set_option('display.max_columns', 3000)
pd.options.display.max_columns = 1600
pd.options.display.max_rows = 160

# %%
YPred
# Out:
#                     0
# 2019-01-01  11.763722
# 2019-01-02  12.846665
# 2019-01-03  12.247855
# 2019-01-04  11.141347
# 2019-01-05  11.558373
# 2019-01-06  12.309358
# 2019-01-07  12.846665
# 2019-01-08  11.558373
# 2019-01-09  12.846665
# 2019-01-10  11.763722
# 2019-01-11  12.097880
# 2019-01-12  11.141347
# 2019-01-13  12.966411
# 2019-01-14  12.309358
# 2019-01-15  12.097880
# 2019-01-16  11.763722
# 2019-01-17  11.141347
# 2019-01-18  12.097880
# 2019-01-19  11.558373
# 2019-01-20  12.097880
# 2019-01-21  12.247855
# 2019-01-22  12.247855
# 2019-01-23  11.141347
# 2019-01-24  12.097880
# 2019-01-25  11.558373
# 2019-01-26  12.097880
# 2019-01-27  12.097880
# 2019-01-28  12.309358
# 2019-01-29  12.247855
# 2019-01-30  11.763722
# 2019-01-31  11.558373
# 2019-02-01  12.247855
# 2019-02-02  12.247855
# 2019-02-03  12.247855
# 2019-02-04  11.763722
# 2019-02-05  12.247855
# 2019-02-06  12.247855
# 2019-02-07  11.141347
# 2019-02-08  12.097880
# 2019-02-09   9.740111
# 2019-02-10  11.141347
# 2019-02-11  11.558373
# 2019-02-12  12.247855
# 2019-02-13  11.141347
# 2019-02-14  11.763722
# 2019-02-15  11.763722
# 2019-02-16  11.763722
